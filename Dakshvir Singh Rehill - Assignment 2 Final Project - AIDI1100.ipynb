# %% [markdown]
# # News and Stock Scraper - Assignment 2 and Final Project
# ***
# ## Durham College - School Of Business, IT and Management (BITM)
# ***
# ## INTRODUCTION TO AI DEVELOPMENT - AIDI 1100 - 02
# ***
# ## Dakshvir Singh Rehill - 100799805
# ***
# ## Submission Date : 18/11/2020
# ***
# ***
# ***

# %%
import NewsScraper as ns

# %%
ns.period = 50
ns.url = 'https://www.prnewswire.com/news-releases/news-releases-list/'

# %%
ns.fetchData()
# Out:
# [2020-11-18 12:53:40,370] [timeloop] [INFO] Starting Timeloop..
# [2020-11-18 12:53:40,370] [timeloop] [INFO] Starting Timeloop..
# [2020-11-18 12:53:40,376] [timeloop] [INFO] Registered job <function parseAndScrape at 0x0000019B3D15E8B0>
# [2020-11-18 12:53:40,376] [timeloop] [INFO] Registered job <function parseAndScrape at 0x0000019B3D15E8B0>
# [2020-11-18 12:53:40,377] [timeloop] [INFO] Timeloop now started. Jobs will run based on the interval set
# [2020-11-18 12:53:40,377] [timeloop] [INFO] Timeloop now started. Jobs will run based on the interval set
#  <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="/content/dam/prnewswire/icons/2019-Q4-PRN-Icon-32-32.png" rel="icon" type="image/png"/>
# ...

# %%
ns.stopDatafetch()
# Out:
# [2020-11-18 12:54:54,057] [timeloop] [INFO] Stopping job <function parseAndScrape at 0x0000019B3D15E8B0>
# [2020-11-18 12:54:54,057] [timeloop] [INFO] Stopping job <function parseAndScrape at 0x0000019B3D15E8B0>
# [2020-11-18 12:54:54,060] [timeloop] [INFO] Timeloop exited.
# [2020-11-18 12:54:54,060] [timeloop] [INFO] Timeloop exited.
